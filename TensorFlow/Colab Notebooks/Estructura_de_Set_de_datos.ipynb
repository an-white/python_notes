# %% [markdown]
# **Set de datos**
#
# Se deben dividir en entrenamiento, validacion, test
#
# **Set de entrenamiento**
# Para entrenar
#
# **Set de validacion**
# Data de validacion para poder ajustar los hiperparametros del algoritmo
#
# **set de test**
# Data para probar el algoritmo
#
# Por cuestion de etica se debe hacer un test con datos que jamas haya visto el algoritmo
